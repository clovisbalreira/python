# %%
#Passo a passo do projeto
#Passo 1: Entrar no sistema da empresa
import pyautogui
import time

#pyautogui.write -> escrever texto
#pyautogui.press -> escrever 1 tecla
#pyautogui.click -> clicar em algum lugar da dela
#pyautogui.hotkey -> compinação de teclas

#abrir o navegador (chrome)
pyautogui.press('win')
pyautogui.PAUSE = 1
pyautogui.write('chrome')
pyautogui.press('enter')
pyautogui.press('enter')
time.sleep(10)

#entrar no link
pyautogui.write('https://dlp.hashtagtreinamentos.com/python/intensivao/login')
pyautogui.press('enter')

# %%
#Passo 2: fazer login

#selecionar o campo de email
pyautogui.click(x=759, y=360)
time.sleep(5)
pyautogui.write('clovisbalreira@gmail.com')
#selecionar o campo de senha
pyautogui.press('tab')
pyautogui.write('aaaa')
#selecionar o botão
pyautogui.press('tab')
#time.sleep(5)
pyautogui.press('enter')

# %%
#Passo 3: Importar a base de produtos pra cadastrar
import pandas as pd
tabela = pd.read_csv('../csv/produtos.csv')
print(tabela)
# Out:
#          codigo       marca        tipo  categoria  preco_unitario  custo  \
# 0    MOLO000251    Logitech       Mouse          1           25.95    6.5
# 1    MOLO000192    Logitech       Mouse          2           19.95    5.0
# 2    CAHA000251     Hashtag      Camisa          1           25.00   11.0
# 3    CAHA000252     Hashtag      Camisa          2           25.00   11.0
# 4    MOMU000111  Multilaser       Mouse          1           11.99    3.4
# ..          ...         ...         ...        ...             ...    ...
# 288  ACAP000192       Apple  Acessorios          2           19.00    3.8
# 289  ACSA0009.3     Samsung  Acessorios          3            9.55    2.1
# 290  CEMO000271    Motorola     Celular          1          279.00   72.5
# 291  FOMO000152    Motorola        Fone          2          150.00   33.0
# 292  CEMO000223    Motorola     Celular          3          229.00   55.0
#
#                   obs
# 0                 NaN
# 1                 NaN
# ...

# %%
#Passo 4: Cadastrar um produto
linha = 0
#capturar posição do mouse
#time.sleep(5)
#print(pyautogui.position())
#clicar no campo do codigo
#pyautogui.click(x=646, y=244)
#pegar da tabela o valor do campo que a gente quer preecher
#codigo = tabela.loc[linha, 'codigo']
#preencher o campo
#pyautogui.write(str(codigo))
#passar para o proximo campo
#pyautogui.press('tab')
#preencher o campo
#pyautogui.write(str(tabela.loc[linha, 'marca']))
#passar para o proximo campo
#pyautogui.press('tab')
#preencher o campo
#pyautogui.write(str(tabela.loc[linha, 'tipo']))
#passar para o proximo campo
#pyautogui.press('tab')
#preencher o campo
#pyautogui.write(str(tabela.loc[linha, 'categoria']))
#passar para o proximo campo
#pyautogui.press('tab')
#preencher o campo
#pyautogui.write(str(tabela.loc[linha, 'preco_unitario']))
#passar para o proximo campo
#pyautogui.press('tab')
#preencher o campo
#pyautogui.write(str(tabela.loc[linha, 'custo']))
#passar para o proximo campo
#pyautogui.press('tab')
#preencher o campo
#if not pd.isna(tabela.loc[linha, 'obs']):
#    pyautogui.write(str(tabela.loc[linha, 'obs']))
#passar para o proximo campo
#pyautogui.press('tab')
#pyautogui.press('enter')
#dar scroll pra cima
#pyautogui.scroll(5000)

# %%
#Passo 5: Repetir o processo até o fim
#for linha in tabela.index:
for linha in range(0, 3):
    pyautogui.click(x=646, y=244)
    #pegar da tabela o valor do campo que a gente quer preecher
    codigo = tabela.loc[linha, 'codigo']
    #preencher o campo
    pyautogui.write(str(codigo))
    #passar para o proximo campo
    pyautogui.press('tab')
    #preencher o campo
    pyautogui.write(str(tabela.loc[linha, 'marca']))
    #passar para o proximo campo
    pyautogui.press('tab')
    #preencher o campo
    pyautogui.write(str(tabela.loc[linha, 'tipo']))
    #passar para o proximo campo
    pyautogui.press('tab')
    #preencher o campo
    pyautogui.write(str(tabela.loc[linha, 'categoria']))
    #passar para o proximo campo
    pyautogui.press('tab')
    #preencher o campo
    pyautogui.write(str(tabela.loc[linha, 'preco_unitario']))
    #passar para o proximo campo
    pyautogui.press('tab')
    #preencher o campo
    pyautogui.write(str(tabela.loc[linha, 'custo']))
    #passar para o proximo campo
    pyautogui.press('tab')
    #preencher o campo5.0       
    if not pd.isna(tabela.loc[linha, 'obs']):
        pyautogui.write(str(tabela.loc[linha, 'obs']))
    #passar para o proximo campo
    pyautogui.press('tab')
    pyautogui.press('enter')
    #dar scroll pra cima
    pyautogui.scroll(5000)
pyautogui.scroll(-5000)
